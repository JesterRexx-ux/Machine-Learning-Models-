# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('adult.csv')

# %%
df.head(4)
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K

# %%
df.shape
# Out:
# (32561, 15)

# %%
count_row = df.shape[0]

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education.num',
#        'marital.status', 'occupation', 'relationship', 'race', 'sex',
#        'capital.gain', 'capital.loss', 'hours.per.week', 'native.country',
#        'income'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
sns.heatmap(df.isnull())

# %%
df.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df['capital.gain'].hist()

# %%
df['capital.loss'].hist()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df['workclass'].value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
plt.rcParams['figure.figsize'] = (18, 9)
sns.countplot(df['workclass'])

# %%
df['education'].value_counts()
# Out:
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
plt.rcParams['figure.figsize'] = (18, 9)
sns.countplot(df['education'])

# %%
df['occupation'].value_counts()
# Out:
# Prof-specialty       4140
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
plt.rcParams['figure.figsize'] = (25, 15)
sns.countplot(df['occupation'],linewidth=5)

# %%
df['sex'].value_counts()
# Out:
# Male      21790
# Female    10771
# Name: sex, dtype: int64

# %%
plt.rcParams['figure.figsize'] = (18, 9)
sns.countplot(df['sex'])

# %%
df['race'].value_counts()
# Out:
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
plt.rcParams['figure.figsize'] = (18, 9)
sns.countplot(df['race'])

# %%
df['native.country'].value_counts()
# Out:
# United-States                 29170
# Mexico                          643
# ?                               583
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...

# %%
a=df['native.country'].value_counts()

# %%
a/count_row
# Out:
# United-States                 0.895857
# Mexico                        0.019748
# ?                             0.017905
# Philippines                   0.006081
# Germany                       0.004207
# Canada                        0.003716
# Puerto-Rico                   0.003501
# El-Salvador                   0.003255
# India                         0.003071
# Cuba                          0.002918
# England                       0.002764
# Jamaica                       0.002488
# South                         0.002457
# China                         0.002303
# Italy                         0.002242
# Dominican-Republic            0.002150
# Vietnam                       0.002058
# Guatemala                     0.001966
# Japan                         0.001904
# Poland                        0.001843
# Columbia                      0.001812
# Taiwan                        0.001566
# Haiti                         0.001351
# Iran                          0.001321
# ...

# %%
df['marital.status'].value_counts()
# Out:
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital.status, dtype: int64

# %%
plt.rcParams['figure.figsize'] = (18, 9)
sns.countplot(df['marital.status'])

# %%
plt.rcParams['figure.figsize'] = (18, 9)
sns.countplot(df['Relationship'])

# %%
df.head(2)
# Out:
#    Age Workclass  fnlwgt Education  Education Num Marital Status  \
# 0   90         ?   77053   HS-grad              9        Widowed
# 1   82   Private  132870   HS-grad              9        Widowed
#
#         Occupation   Relationship   Race  Gender  Capital Gain  Capital Loss  \
# 0                ?  Not-in-family  White  Female             0          4356
# 1  Exec-managerial  Not-in-family  White  Female             0          4356
#
#    Hours/Week Native Country income
# 0          40  United-States  <=50K
# 1          18  United-States  <=50K

# %%
df = df.rename(columns = {"age":"Age","workclass":"Workclass","education":"Education","education.num":"Education Num",
                         "marital.status":"Marital Status","occupation":"Occupation","relationship":"Relationship",
                         "race":"Race","sex":"Gender","capital.gain":"Capital Gain","capital.loss":"Capital Loss",
                         "hours.per.week":"Hours/Week","native.country":"Native Country"})

# %%
df.head(2)
# Out:
#    Age Workclass  fnlwgt Education  Education Num Marital Status  \
# 0   90         ?   77053   HS-grad              9        Widowed
# 1   82   Private  132870   HS-grad              9        Widowed
#
#         Occupation   Relationship   Race  Gender  Capital Gain  Capital Loss  \
# 0                ?  Not-in-family  White  Female             0          4356
# 1  Exec-managerial  Not-in-family  White  Female             0          4356
#
#    Hours/Week Native Country income
# 0          40  United-States  <=50K
# 1          18  United-States  <=50K

# %%
sns.countplot(x="Education", hue="Workclass", data=df)

# %%
sns.countplot(x="Education", hue="Workclass", data=df)

# %%
df['Age'].hist()

# %%
plt.rcParams['figure.figsize'] = (25, 9)
sns.countplot(x="Occupation", hue="Workclass", data=df)

# %%
plt.rcParams['figure.figsize'] = (25, 9)
sns.countplot(x="Education", hue="Occupation", data=df)

# %%
df.head(2)
# Out:
#    Age Workclass  fnlwgt Education  Education Num Marital Status  \
# 0   90         ?   77053   HS-grad              9        Widowed
# 1   82   Private  132870   HS-grad              9        Widowed
#
#         Occupation   Relationship   Race  Gender  Capital Gain  Capital Loss  \
# 0                ?  Not-in-family  White  Female             0          4356
# 1  Exec-managerial  Not-in-family  White  Female             0          4356
#
#    Hours/Week Native Country income
# 0          40  United-States  <=50K
# 1          18  United-States  <=50K

# %%
df = df[(df.astype(str) != '?').all(axis=1)]

# %%
df.head(2)
# Out:
#    Age Workclass  fnlwgt Education  Education Num Marital Status  \
# 1   82   Private  132870   HS-grad              9        Widowed
# 3   54   Private  140359   7th-8th              4       Divorced
#
#           Occupation   Relationship   Race  Gender  Capital Gain  \
# 1    Exec-managerial  Not-in-family  White  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
#
#    Capital Loss  Hours/Week Native Country income
# 1          4356          18  United-States  <=50K
# 3          3900          40  United-States  <=50K

# %%
df['Hours/Week'].hist()

# %%
df.shape
# Out:
# (30162, 15)

# %%
df.shape
# Out:
# (32561, 15)

# %%
plt.rcParams['figure.figsize'] = (25, 9)
sns.countplot(x="Education", hue="Gender", data=df)

# %%
plt.rcParams['figure.figsize'] = (25, 9)
sns.countplot(x="Education", hue="Race", data=df)

# %%
plt.rcParams['figure.figsize'] = (25, 9)
sns.countplot(x="Education", hue="Relationship", data=df)

# %%
plt.rcParams['figure.figsize'] = (25, 9)
sns.countplot(x="Education", hue="Marital Status", data=df)

# %%
plt.rcParams['figure.figsize'] = (25, 9)
sns.countplot(x="Occupation", hue="Race", data=df)

# %%
plt.rcParams['figure.figsize'] = (25, 9)
sns.countplot(x="Occupation", hue="Gender", data=df)

# %%
plt.rcParams['figure.figsize'] = (25, 9)
sns.countplot(x="Occupation", hue="Marital Status", data=df)

# %%
df.head(2)
# Out:
#    Age Workclass  fnlwgt Education  Education Num Marital Status  \
# 1   82   Private  132870   HS-grad              9        Widowed
# 3   54   Private  140359   7th-8th              4       Divorced
#
#           Occupation   Relationship   Race  Gender  Capital Gain  \
# 1    Exec-managerial  Not-in-family  White  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
#
#    Capital Loss  Hours/Week Native Country income
# 1          4356          18  United-States  <=50K
# 3          3900          40  United-States  <=50K

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['Gender'] = le.fit_transform(df['Gender'])

# %%
df['Relationship'] = le.fit_transform(df['Relationship'])
df['Native Country'] = le.fit_transform(df['Native Country'])
df['Education Num'] = le.fit_transform(df['Education Num'])
df['Race'] = le.fit_transform(df['Race'])
df['Native Country'] = le.fit_transform(df['Native Country'])

# %%
df['Workclass'] = le.fit_transform(df['Workclass'])
df['Occupation'] = le.fit_transform(df['Occupation'])
df['Education'] = le.fit_transform(df['Education'])

# %%
df.head(2)
# Out:
#    Age  Workclass  fnlwgt  Education  Education Num Marital Status  \
# 1   82          2  132870         11              8        Widowed
# 3   54          2  140359          5              3       Divorced
#
#    Occupation  Relationship  Race  Gender  Capital Gain  Capital Loss  \
# 1           3             1     4       0             0          4356
# 3           6             4     4       0             0          3900
#
#    Hours/Week  Native Country income
# 1          18              38  <=50K
# 3          40              38  <=50K

# %%
df['income'].value_counts()
# Out:
# <=50K    22654
# >50K      7508
# Name: income, dtype: int64

# %%
for i in df['income']:
    if i==('<=50K'):
        df.loc[(df['income'] == '<=50K'),'income']=45000
# Out:
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# >50K
# >50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# >50K
# >50K
# >50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# >50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# <=50K
# ...

# %%
df.loc[(df['income'] == '<=50K'),'income']=45000

# %%
df.loc[(df['income'] == '>50K'),'income']=55000

# %%
df['income']
# Out:
# 1        45000
# 3        45000
# 4        45000
# 5        45000
# 6        45000
#          ...
# 32556    45000
# 32557    45000
# 32558    55000
# 32559    45000
# 32560    45000
# Name: income, Length: 30162, dtype: object

# %%
df['income'] = df['income'].apply(int)
df.dtypes
# Out:
# Age                int64
# Workclass          int64
# fnlwgt             int64
# Education          int64
# Education Num      int64
# Marital Status    object
# Occupation         int64
# Relationship       int64
# Race               int64
# Gender             int64
# Capital Gain       int64
# Capital Loss       int64
# Hours/Week         int64
# Native Country     int64
# income             int64
# dtype: object

# %%
df1 = df.drop(['Marital Status'], axis = 1)

# %%
df1['Relationship'].unique()
# Out:
# array([1, 4, 3, 2, 0, 5])

# %%
df1.head(2)
# Out:
#    Age  Workclass  fnlwgt  Education  Education Num  Occupation  Relationship  \
# 1   82          2  132870         11              8           3             1
# 3   54          2  140359          5              3           6             4
#
#    Race  Gender  Capital Gain  Capital Loss  Hours/Week  Native Country  \
# 1     4       0             0          4356          18              38
# 3     4       0             0          3900          40              38
#
#    income
# 1   45000
# 3   45000

# %%
y = df1['income']

# now removing the purchase column from the dataset
data = df1.drop(['income'], axis = 1)

x = df1

# checking the shapes of x and y
print("Shape of x: ", df1.shape)
print("Shape of y: ", df1.shape)
# Out:
# Shape of x:  (30162, 14)
# Shape of y:  (30162, 14)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 15)

print("Shape of x_train: ", x_train.shape)
print("Shape of x_test: ", x_test.shape)
print("Shape of y_train: ", y_train.shape)
print("Shape of y_test: ",y_test.shape)
# Out:
# Shape of x_train:  (21113, 14)
# Shape of x_test:  (9049, 14)
# Shape of y_train:  (21113,)
# Shape of y_test:  (9049,)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

from math import *

model = Ridge()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)


# finding the mean_squared error
mse = mean_squared_error(y_test, y_pred)
print("RMSE Error:", np.sqrt(mse))

# finding the r2 score or the variance
r2 = r2_score(y_test, y_pred)
print("R2 Score:", r2)
# Out:
# RMSE Error: 0.2381990630899422
# R2 Score: 0.9999999969456085

# %%
from sklearn.linear_model import LogisticRegression
log=LogisticRegression()
log.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=log.predict(x_test)

# %%
print('Agar accuracy aaai to aisi aayegi: ',(log.score(x_test,y_test)))
# Out:
# Agar accuracy aaai to aisi aayegi:  1.0

# %%
from sklearn.linear_model import LinearRegression
lin=LinearRegression()
lin.fit(x_train,y_train)
y_pred=lin.predict(x_test)

# %%
print('Training Set Score:{:.2f}'.format(lin.score(x_train,y_train)))
print('Test set Score:{:.2f}'.format(lin.score(x_test,y_test)))
# Out:
# Training Set Score:1.00
# Test set Score:1.00

# %%
Q1 = df1.quantile(0.25)
Q3 = df1.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# Age              20.0
# Education Num     3.0
# Capital Gain      0.0
# Capital Loss      0.0
# Hours/Week        5.0
# dtype: float64

# %%
outliers=[]
def lo(data):
    threshold=3
    mean=np.mean(data)
    std=np.std(data)
    
    for i in data:
        z_score=(i-mean)/std
        if np.abs(z_score)>threshold:
            outliers.append(z_score)
    return outliers

# %%
a=lo(df['Capital Gain'])

# %%
a[1]
# Out:
# 13.394577908470211

# %%
q1,q3=np.percentile(df['Capital Gain'],[25,75])

# %%
print(q1,q3)
# Out:
# 0.0 0.0
